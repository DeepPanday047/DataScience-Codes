# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv('census-income_.csv',na_values='?',skipinitialspace=True)
data.tail()
# Out:
#        age     workclass  fnlwgt   education  education-num  \
# 32556   27       Private  257302  Assoc-acdm             12
# 32557   40       Private  154374     HS-grad              9
# 32558   58       Private  151910     HS-grad              9
# 32559   22       Private  201490     HS-grad              9
# 32560   52  Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation relationship   race     sex  \
# 32556  Married-civ-spouse       Tech-support         Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 32558             Widowed       Adm-clerical    Unmarried  White  Female
# 32559       Never-married       Adm-clerical    Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country Unnamed: 14
# 32556             0             0              38  United-States       <=50K
# ...

# %%
data.shape
# Out:
# (32561, 15)

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'Unnamed: 14'],
#       dtype='object')

# %%
data.columns = data.columns.str.replace(' ','_')

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'Unnamed:_14'],
#       dtype='object')

# %%
data.columns = data.columns.str.replace('-','.')

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'Unnamed:_14'],
#       dtype='object')

# %%
# data preprocessing
# 1 replace all MV with NA
# 2  remove all ro

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# Unnamed:_14       0
# dtype: int64

# %%
#Data Manipulation
#Q1 Extractracting the “education” column and store it in “census_ed” . 
census_ed=data[['education']]
census_ed.head()
# Out:
#    education
# 0  Bachelors
# 1  Bachelors
# 2    HS-grad
# 3       11th
# 4  Bachelors

# %%
#) Q2 .Extracting all the columns from “age” to “relationship” and store it in “census_seq”.
census_seq=data.iloc[:,0:8]
census_seq.head()
# Out:
#    age         workclass  fnlwgt  education  education.num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital.status         occupation   relationship
# 0       Never-married       Adm-clerical  Not-in-family
# 1  Married-civ-spouse    Exec-managerial        Husband
# 2            Divorced  Handlers-cleaners  Not-in-family
# 3  Married-civ-spouse  Handlers-cleaners        Husband
# 4  Married-civ-spouse     Prof-specialty           Wife

# %%
# Second method
census_seq = data.loc[:,'age':'relationship']
census_seq
# Out:
#        age         workclass  fnlwgt   education  education.num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital.status         occupation   relationship
# 0           Never-married       Adm-clerical  Not-in-family
# 1      Married-civ-spouse    Exec-managerial        Husband
# ...

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'Unnamed:_14'],
#       dtype='object')

# %%
#Q3 Extract the column number “0”, “5”, “11” and store it in “census_col”.
census_col=data.iloc[:,[0,5,11]]
census_col.head(10)
# Out:
#    age         marital.status  capital.loss
# 0   39          Never-married             0
# 1   50     Married-civ-spouse             0
# 2   38               Divorced             0
# 3   53     Married-civ-spouse             0
# 4   28     Married-civ-spouse             0
# 5   37     Married-civ-spouse             0
# 6   49  Married-spouse-absent             0
# 7   52     Married-civ-spouse             0
# 8   31          Never-married             0
# 9   42     Married-civ-spouse             0

# %%
#)Q3. Extracting all the male employees who work in state-gov and store it in “male_gov”.
male_gov=data[(data['workclass']=='State-gov') & (data['sex']=='Male')]
male_gov.head()
# Out:
#      age  workclass  fnlwgt     education  education.num      marital.status  \
# 0     39  State-gov   77516     Bachelors             13       Never-married
# 11    30  State-gov  141297     Bachelors             13  Married-civ-spouse
# 34    22  State-gov  311512  Some-college             10  Married-civ-spouse
# 48    41  State-gov  101603     Assoc-voc             11  Married-civ-spouse
# 123   29  State-gov  267989     Bachelors             13  Married-civ-spouse
#
#          occupation   relationship                race   sex  capital.gain  \
# 0      Adm-clerical  Not-in-family               White  Male          2174
# 11   Prof-specialty        Husband  Asian-Pac-Islander  Male             0
# 34    Other-service        Husband               Black  Male             0
# 48     Craft-repair        Husband               White  Male             0
# 123  Prof-specialty        Husband               White  Male             0
#
# ...

# %%
male_gov.shape
# Out:
# (795, 15)

# %%
#Extracting all Female employees who work in Private
female_pvt=data[(data['workclass']=='Private') & (data['sex']=='Female')]
female_pvt.head()
# Out:
#     age workclass  fnlwgt  education  education.num         marital.status  \
# 4    28   Private  338409  Bachelors             13     Married-civ-spouse
# 5    37   Private  284582    Masters             14     Married-civ-spouse
# 6    49   Private  160187        9th              5  Married-spouse-absent
# 8    31   Private   45781    Masters             14          Never-married
# 12   23   Private  122272  Bachelors             13          Never-married
#
#          occupation   relationship   race     sex  capital.gain  capital.loss  \
# 4    Prof-specialty           Wife  Black  Female             0             0
# 5   Exec-managerial           Wife  White  Female             0             0
# 6     Other-service  Not-in-family  Black  Female             0             0
# 8    Prof-specialty  Not-in-family  White  Female         14084             0
# 12     Adm-clerical      Own-child  White  Female             0             0
#
#     hours.per.week native.country Unnamed:_14
# ...

# %%
female_pvt.shape
# Out:
# (7642, 15)

# %%
#Q4 Extract all the 39 year olds who either have a bachelor's degree or who are native of the United States and store the result in “census_us”.
#We are writing a condition where age should be 39 and storing it in census. This condition is then taken and applied on the 
#next point to get the result.
census=data[(data['age']==39)]
#census
census_us=census[(census['education']=='Bachelors') | (census['native.country']==' United-States')]
census_us.head()
# Out:
#       age     workclass  fnlwgt  education  education.num      marital.status  \
# 0      39     State-gov   77516  Bachelors             13       Never-married
# 848    39       Private  138192  Bachelors             13  Married-civ-spouse
# 915    39       Private  202027  Bachelors             13  Married-civ-spouse
# 999    39  Self-emp-inc  329980  Bachelors             13  Married-civ-spouse
# 1336   39       Private  174938  Bachelors             13       Never-married
#
#            occupation   relationship   race   sex  capital.gain  capital.loss  \
# 0        Adm-clerical  Not-in-family  White  Male          2174             0
# 848      Craft-repair        Husband  White  Male             0             0
# 915   Exec-managerial        Husband  White  Male         15024             0
# 999   Exec-managerial        Husband  White  Male         15024             0
# 1336   Prof-specialty  Not-in-family  White  Male             0             0
#
# ...

# %%
census
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 0       39         State-gov   77516     Bachelors             13
# 28      39           Private  367260       HS-grad              9
# 129     39           Private  365739  Some-college             10
# 166     39       Federal-gov  235485    Assoc-acdm             12
# 320     39  Self-emp-not-inc  174308       HS-grad              9
# ...    ...               ...     ...           ...            ...
# 32260   39       Federal-gov  232036  Some-college             10
# 32378   39           Private  214896       HS-grad              9
# 32428   39       Federal-gov  110622     Bachelors             13
# 32468   39  Self-emp-not-inc  193689       HS-grad              9
# 32545   39         Local-gov  111499    Assoc-acdm             12
#
#            marital.status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %%
# Q5 sample() helps us to get random rows
census_200=data.sample(200)
census_200
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 5602    59   Private  348430     Bachelors             13  Married-civ-spouse
# 29386   25   Private  178037       HS-grad              9       Never-married
# 20445   24   Private  153583  Some-college             10       Never-married
# 4734    22   Private  239806     Assoc-voc             11       Never-married
# 14519   39   Private   87556       Masters             14       Never-married
# ...    ...       ...     ...           ...            ...                 ...
# 13912   34   Private   42596  Some-college             10  Married-civ-spouse
# 17352   23   Private  149396       HS-grad              9       Never-married
# 25671   24   Private  100605  Some-college             10       Never-married
# 32424   35   Private  102268     Bachelors             13  Married-civ-spouse
# 4073    33   Private  131776     Bachelors             13            Divorced
#
# ...

# %%
#Q6 . Getting the count of different levels of the “workclass” column.
#value_counts() helps us to get the total count of all elements present in a particular column.
data[['workclass']].value_counts()
# Out:
# workclass
# Private             22286
# Self-emp-not-inc     2499
# Local-gov            2067
# State-gov            1279
# Self-emp-inc         1074
# Federal-gov           943
# Without-pay            14
# dtype: int64

# %%
#Q7 Here we are calculating the mean of capital gain on the bases of work class
data.groupby(['workclass'])['capital.gain'].mean()
# Out:
# workclass
# Federal-gov          832.321315
# Local-gov            829.230285
# Private              879.858207
# Self-emp-inc        4810.746741
# Self-emp-not-inc    1913.134454
# State-gov            684.306489
# Without-pay          487.857143
# Name: capital.gain, dtype: float64

# %%
df1 = data.rename(columns = {'Unnamed:_14':'income'}, inplace = True)
data.head()
# Out:
#    age         workclass  fnlwgt  education  education.num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital.status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital.gain  capital.loss  hours.per.week native.country income
# 0          2174             0              40  United-States  <=50K
# ...

# %% [markdown]
# # #Linear Regression

# %%
X =data[['education.num']]
y =data['hours.per.week']

# %%
X.head()
# Out:
#    education.num
# 0             13
# 1             13
# 2              9
# 3              7
# 4             13

# %%
X.shape
# Out:
# (30162, 1)

# %%
y.shape
# Out:
# (30162,)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred =LR.predict(X_test)

# %%
error =y_test-y_pred
error
# Out:
# 234      10.691890
# 26879    -0.209680
# 19182     9.790320
# 13485     4.790320
# 9625     -2.941967
#            ...
# 22583    -5.892752
# 32131     0.691890
# 24450     2.058033
# 8389    -10.209680
# 4235     -2.941967
# Name: hours.per.week, Length: 9049, dtype: float64

# %%
from sklearn.metrics import mean_squared_error

# %%
print('mean_squared_error :',mean_squared_error(y_test,y_pred))

print('root-mean-square error :',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# mean_squared_error : 137.81263845871413
# root-mean-square error : 11.73936277907426

# %%
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
X = data[['occupation']]

# %%
data['income'].value_counts()
# Out:
# <=50K    22654
# >50K      7508
# Name: income, dtype: int64

# %%
y=data['income'].replace('<=50K',0).replace('>50K',1)
y.value_counts()
# Out:
# 0    22654
# 1     7508
# Name: income, dtype: int64

# %%
# labelencoding
L = LabelEncoder()

# %%
X= L.fit_transform(X)
# Out:
# C:\Users\pande\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
X = pd.DataFrame(X)

# %%
X.head()
# Out:
#    0
# 0  0
# 1  3
# 2  5
# 3  5
# 4  9

# %%
X.value_counts()
# Out:
# 9     4038
# 2     4030
# 3     3992
# 0     3721
# 11    3584
# 7     3212
# 6     1966
# 13    1572
# 5     1350
# 4      989
# 12     912
# 10     644
# 8      143
# 1        9
# dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.65,random_state=1)
LOG = LogisticRegression()
LOG.fit(X_train,y_train)
y_pred = LOG.predict(X_test)

print('Confusion Matrix')
print(confusion_matrix(y_test,y_pred))
print('Accuracy score')
print(accuracy_score(y_test,y_pred))
# Out:
# Confusion Matrix
# [[7932    0]
#  [2625    0]]
# Accuracy score
# 0.7513498152884343

# %% [markdown]
# # Multiple LOGR

# %%
d = data[['age','workclass','education']]
d.head()
# Out:
#    age         workclass  education
# 0   39         State-gov  Bachelors
# 1   50  Self-emp-not-inc  Bachelors
# 2   38           Private    HS-grad
# 3   53           Private       11th
# 4   28           Private  Bachelors

# %%
X = d.apply(L.fit_transform)
X.head()
# Out:
#    age  workclass  education
# 0   22          5          9
# 1   33          4          9
# 2   21          2         11
# 3   36          2          1
# 4   11          2          9

# %%
y=data['income'].replace('<=50K',0).replace('>50K',1)
y.value_counts()
# Out:
# 0    22654
# 1     7508
# Name: income, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.80,random_state=1)
LOG = LogisticRegression()
LOG.fit(X_train,y_train)
y_pred = LOG.predict(X_test)

print('Confusion Matrix')
print(confusion_matrix(y_test,y_pred))
print('Accuracy score')
print(accuracy_score(y_test,y_pred))
# Out:
# Confusion Matrix
# [[4349  134]
#  [1499   51]]
# Accuracy score
# 0.7293220619923753

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
data.head()
# Out:
#    age         workclass  fnlwgt  education  education.num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital.status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital.gain  capital.loss  hours.per.week native.country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
data.education= data.education.replace(['Preschool', '1st-4th', '5th-6th', '7th-8th', '9th','10th', '11th', '12th'], 'School')
data.education = data.education.replace(['Assoc-voc', 'Assoc-acdm', 'Prof-school', 'Some-college'], 'Higher')
data['marital.status']= data['marital.status'].replace(['Married-civ-spouse', 'Married-AF-spouse'], 'married')
data['marital.status']= data['marital.status'].replace(['Never-married'], 'not-married')
data['marital.status']= data['marital.status'].replace(['Divorced', 'Separated','Widowed','Married-spouse-absent'], 'other')
data.income = data.income.replace('<=50K', 0)
data.income = data.income.replace('>50K', 1)
data.head()
# Out:
#    age         workclass  fnlwgt  education  education.num marital.status  \
# 0   39         State-gov   77516  Bachelors             13    not-married
# 1   50  Self-emp-not-inc   83311  Bachelors             13        married
# 2   38           Private  215646    HS-grad              9          other
# 3   53           Private  234721     School              7        married
# 4   28           Private  338409  Bachelors             13        married
#
#           occupation   relationship   race     sex  capital.gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital.loss  hours.per.week native.country  income
# 0             0              40  United-States       0
# ...

# %%
data = data.apply(L.fit_transform)
data.head()
# Out:
#    age  workclass  fnlwgt  education  education.num  marital.status  \
# 0   22          5    2491          0             12               1
# 1   33          4    2727          0             12               0
# 2   21          2   13188          2              8               2
# 3   36          2   14354          5              6               0
# 4   11          2   18120          0             12               0
#
#    occupation  relationship  race  sex  capital.gain  capital.loss  \
# 0           0             1     4    1            24             0
# 1           3             0     4    1             0             0
# 2           5             1     4    1             0             0
# 3           5             0     2    1             0             0
# 4           9             5     2    0             0             0
#
#    hours.per.week  native.country  income
# 0              39              38       0
# 1              12              38       0
# ...

# %%
X = data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.70,random_state=1)
DT = DecisionTreeClassifier()
DT.fit(X_train,y_train)
y_pred = DT.predict(X_test)


print('Confusion Matrix')
print(confusion_matrix(y_test,y_pred))
print('Accuracy score')
print(accuracy_score(y_test,y_pred))
# Out:
# Confusion Matrix
# [[5879  890]
#  [ 872 1408]]
# Accuracy score
# 0.8052823516410653

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
RF= RandomForestClassifier(n_estimators=300)
RF.fit(X_train,y_train)
y_pred = RF.predict(X_test)

print('Confusion Matrix')
print(confusion_matrix(y_test,y_pred))
print('Accuracy score')
print(accuracy_score(y_test,y_pred))
# Out:
# Confusion Matrix
# [[6308  461]
#  [ 821 1459]]
# Accuracy score
# 0.8583268869488341

# %% [markdown]
# # Data Visulization

# %%
data.head()
# Out:
#    age  workclass  fnlwgt  education  education.num  marital.status  \
# 0   22          5    2491          0             12               1
# 1   33          4    2727          0             12               0
# 2   21          2   13188          2              8               2
# 3   36          2   14354          5              6               0
# 4   11          2   18120          0             12               0
#
#    occupation  relationship  race  sex  capital.gain  capital.loss  \
# 0           0             1     4    1            24             0
# 1           3             0     4    1             0             0
# 2           5             1     4    1             0             0
# 3           5             0     2    1             0             0
# 4           9             5     2    0             0             0
#
#    hours.per.week  native.country  income
# 0              39              38       0
# 1              12              38       0
# ...

# %%
data.relationship.unique()
# Out:
# array([1, 0, 5, 3, 4, 2])

# %%
data.race.unique()
# Out:
# array([4, 2, 1, 0, 3])

# %%
data.sex.value_counts()
# Out:
# 1    20380
# 0     9782
# Name: sex, dtype: int64

# %%
# The bar plot

# %%
sns.barplot(data=data,x='relationship',y='race',hue='sex',dodge=True)
plt.xlabel('Categories of Relationship')
plt.ylabel('Count of categories')
plt.title('Distribution of Relationship by Sex')
plt.show()

# %%
#Histogram

# %%
# Histplot
sns.histplot(x=data['age'],bins=50,hue=data['income'],color =['black','white'] , ec="r")
plt.title('Distribution of Age')
plt.show()

# %%
# Scatter plot

# %%
sns.scatterplot(data=data,x='capital.gain',y='hours.per.week',alpha=0.4,size=2,hue='income',label='Yearly Income')
plt.title('Capital Gain VS Hours per Week by Income')
plt.xlabel('Capital Gain')
plt.ylabel('Hours per Week')
plt.legend(loc=0)
plt.show()

# %%
# The Box Plot

# %%
sns.boxplot(data=data,x='education',y='age',hue='sex')
plt.title('Box Plot of age by Sex and Education')
plt.show()
