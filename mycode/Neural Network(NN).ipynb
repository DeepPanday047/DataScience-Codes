# %% [markdown]
# # Simple Linear Regression: Minimal Example

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # 2D Graphs
from mpl_toolkits.mplot3d import  Axes3D # 3D grphs

# %% [markdown]
# # Generate random input to train on

# %%
observations = 1000
xs = np.random.uniform(low=-10,high=10,size=(observations,1))
zs = np.random.uniform(low=-10,high=10,size=(observations,1))

inputs = np.column_stack((xs,zs))

print(inputs.shape)
# Out:
# (1000, 2)

# %% [markdown]
# # Create the Targets we wil aim at

# %%
noise = np.random.uniform(-1,1,(observations,1))
targets = 2*xs - 3*zs + 5 + noise  

print(targets.shape)
# Out:
# (1000, 1)

# %% [markdown]
# # Initialize variables

# %%
init_range = 0.1

weights = np.random.uniform(low=-init_range,high=init_range,size =(2,1))

biases = np.random.uniform(low=-init_range,high=init_range,size =1)

print('Weights :\n',weights)
print('\nBias\n',biases)
# Out:
# Weights :
#  [[ 0.01230182]
#  [-0.07565346]]
#
# Bias
#  [0.01018148]

# %% [markdown]
# # Set a learning rate

# %%
learning_rate = 0.02

# %% [markdown]
# # Train the model

# %%
for i in range(100):
  outputs = np.dot(inputs,weights)+ biases # Y = XW +B (linear eq)
  deltas = outputs-targets

  loss = np.sum(deltas**2)/2/observations # find loss by L2-Norm method
  print(loss)

  deltas_scaled = deltas/observations

  weights = weights-learning_rate*np.dot(inputs.T,deltas_scaled)
#  weights(2x1) = weights(2x1)-learning_rate(1x1)*np.dot(inputs.T(2x1000),deltas_scaled(1000x1))
  biases = biases-learning_rate *np.sum(deltas_scaled)
# Out:
# 0.3967477505833167
# 0.3879123466233375
# 0.3794256637754523
# 0.371273938502129
# 0.36344395049352907
# 0.35592300122706433
# 0.3486988933731816
# 0.3417599110139693
# 0.3350948006425083
# 0.32869275291215616
# 0.32254338510615443
# 0.3166367242991422
# 0.31096319118325993
# 0.3055135845326124
# 0.3002790662808993
# 0.2952511471880121
# 0.29042167307234823
# 0.28578281158651697
# 0.2813270395149923
# 0.27704713057310687
# 0.2729361436876018
# 0.2689874117397342
# 0.26519453075266697
# 0.2615513495056278
# 0.2580519595579774
# 0.2546906856670156
# 0.25146207658398056
# 0.24836089621332388
# 0.2453821151209067
# 0.24252090237736676
# 0.2397726177234066
# 0.2371328040443139
# 0.2345971801414966
# 0.23216163378932086
# 0.22982221506598227
# 0.2275751299475986
# 0.22541673415513674
# 0.22334352724418996
# 0.22135214692802738
# 0.2194393636247013
# 0.21760207521937353
# 0.21583730203336654
# 0.21414218199177804
# 0.2125139659818234
# 0.2109500133943781
# 0.20944778784148957
# ...

# %% [markdown]
# # Print weights and biases and see if we have worked correctly

# %%
print(weights,biases)
# Out:
# [[ 2.00562101]
#  [-2.99905369]] [4.91114293]

# %% [markdown]
# # Plot last outputs vs Targets

# %%
plt.plot(outputs,targets)
plt.xlabel('Outputs')
plt.ylabel('targets')
plt.show()
